# %% [markdown]
# # SJSU MSDS 255 DL, Spring 2024
# Homework 04: Transfer Learning and Bounding Boxes and YOLOV8

# %% [markdown]
# Git: https://github.com/jrgosalvez/data255_DL

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### Object Detection Inference from VIDEO with YOLO8 Transfer Learning

# %% [markdown]
# Source: <br>
# - https://www.youtube.com/watch?app=desktop&v=o4Zd-IeMlSY
# - https://pysource.com/2023/03/28/object-detection-with-yolo-v8-on-mac-m1/
# - https://docs.opencv.org/4.x/d6/d6e/group__imgproc__draw.html#ga5126f47f883d730f633d74f07456c576

# %% [markdown]
# <b>NOTE:</b> YOLOv8 relies on PyTorch as its deep learning framework. NVIDIA NGC Catalog offers additional GPU optimized frameworks for alternative transfer learning models, frameworks, and containers (e.g. NeMO).

# %% [markdown]
# #### Step 1:
# - Collect a source video.
# - YOLO8 accepts the following video formats: .asf, .avi, .gif, .m4v, .mkv, .mov, .mp4, .mpeg, .mpg, .ts, .wmv, .webm.
# - iphone video creates .mp4 videos; I created 5-10 sec street videos and saved them locally.

# %% [markdown]
# #### Steps 2 & 3:
# Conduct inference on video, frame by frame, drawing bounding boxes around detected objects (specifically vehicles) and output a video of the object detection results.

# %%
# check mac systems for GPU
import torch
print(torch.backends.mps.is_available())   # check for Mac M1 GPU
# Out:
# False

# %%
# import openCV, numpy, and ultralytics YOLO8

import cv2
from ultralytics import YOLO
import numpy as np

# %%
# %%time

# load 5-10 sec street intersection video
video = './video_in/rick_boston_01.MOV'

# measure, capture, and config frames
cap = cv2.VideoCapture(video)
frame_width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# count frames and clip video so can clip video to specific time limit
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = frame_count / fps

# Set the start and end times for clipping (6, 8, or 10 if greater than 10 seconds)
start_time = 0
end_time = min(6, duration)

# Set path, name, and video output writer
output_path  = 'output_rick_boston_01.mp4'
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

# load pretrained model, in this case YOLO8, but can be any that do object detection on an image frame
# for YOLO I will use the small version; it is less percise, but faster. Medium is default, can also change to larger more percise
# can also use the base model or the segmentation model by adding -seg before .pt 
model = YOLO('yolov8s.pt') 

# create labels per the output of printing 'results' (see below, commented out)
names = {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# object detection frame loop
while True:
    ret, frame = cap.read()
           
    if ret:
        # current time in seconds
        current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  
        if current_time >= start_time:
            print(f'current_time: {current_time:.3f} | start_time {start_time}')
            
            # Clip the video to 6, 8, 10 seconds
            if current_time <= end_time:
                print(f'current_time: {current_time:.3f} | end_time {end_time}')
                
                # Perform object detection on the frame & check labels - names = 2: 'car', 3: ' motorcycle', 5: 'bus', 7: 'truck'
                results = model(frame, device='cpu')
                #print(results)
                
                # integer is better than float for printing bounding boxes
                result = results[0]
                bboxes = np.array(result.boxes.xyxy.cpu(), dtype='int')  
                #print(bboxes)
                
                # get class labels
                classes = np.array(result.boxes.cls.cpu(), dtype='int')  

                for cls, bbox in zip(classes, bboxes):
                    (x, y, x2, y2) = bbox
                    #print('x', x, 'y', y)
                    
                    # (input, top left, bottom right, color in RGB, line thickness)
                    cv2.rectangle(frame, (x, y), (x2, y2), (0,0,225), 2)  
                    
                    # put class name inside drawing box 5 px in and down 20 px
                    frame_with_boxes = cv2.putText(frame, str(names[cls]), (x+5, y+20), cv2.FONT_HERSHEY_PLAIN, 2,(0,0,225), 3)  
                    cv2.imshow('YOLO8 Object Detection, SJSU MSDA 255 DL, Spring 2024', frame)       
                    
                    # format results back into a video
                    out.write(frame_with_boxes)
                    
            else:
                break
        
        # Break the loop if 'q' key is pressed. waitKey(0) requires key pressing to advance; 1 auto advances image frames of video
        if cv2.waitKey(1) & 0xFF == ord('q'):     
            print('Break Loop')
            break
            
    else:
        break

print()
print('Out of Loop')
print()
        
# Release the video capture and close all windows. NOTE: works in CLI and .py script, but glitchy in Jupyter, requires manual kernel restart.
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# current_time: 0.000 | start_time 0
# current_time: 0.000 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 357.9ms
# Speed: 20.3ms preprocess, 357.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.033 | start_time 0
# current_time: 0.033 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 404.2ms
# Speed: 6.7ms preprocess, 404.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.067 | start_time 0
# current_time: 0.067 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 277.6ms
# Speed: 4.3ms preprocess, 277.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.100 | start_time 0
# current_time: 0.100 | end_time 6
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 276.6ms
# Speed: 6.5ms preprocess, 276.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.133 | start_time 0
# current_time: 0.133 | end_time 6
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 278.6ms
# Speed: 5.7ms preprocess, 278.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.167 | start_time 0
# current_time: 0.167 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 311.0ms
# Speed: 4.8ms preprocess, 311.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.200 | start_time 0
# current_time: 0.200 | end_time 6
#
# 0: 384x640 2 persons, 3 cars, 284.1ms
# Speed: 5.7ms preprocess, 284.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.233 | start_time 0
# current_time: 0.233 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 413.7ms
# Speed: 12.0ms preprocess, 413.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.267 | start_time 0
# current_time: 0.267 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 407.5ms
# Speed: 12.7ms preprocess, 407.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.300 | start_time 0
# current_time: 0.300 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 406.0ms
# Speed: 9.9ms preprocess, 406.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.333 | start_time 0
# current_time: 0.333 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 428.9ms
# Speed: 15.2ms preprocess, 428.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.367 | start_time 0
# current_time: 0.367 | end_time 6
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 285.7ms
# Speed: 7.2ms preprocess, 285.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.400 | start_time 0
# current_time: 0.400 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 334.3ms
# Speed: 5.0ms preprocess, 334.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.433 | start_time 0
# current_time: 0.433 | end_time 6
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 373.0ms
# Speed: 5.8ms preprocess, 373.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.467 | start_time 0
# current_time: 0.467 | end_time 6
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 364.7ms
# Speed: 5.6ms preprocess, 364.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.500 | start_time 0
# current_time: 0.500 | end_time 6
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 342.5ms
# Speed: 4.8ms preprocess, 342.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.533 | start_time 0
# current_time: 0.533 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 369.6ms
# Speed: 7.6ms preprocess, 369.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.567 | start_time 0
# current_time: 0.567 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 445.2ms
# Speed: 4.0ms preprocess, 445.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.600 | start_time 0
# current_time: 0.600 | end_time 6
#
# 0: 384x640 2 persons, 3 cars, 1 bus, 354.2ms
# Speed: 6.6ms preprocess, 354.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.633 | start_time 0
# current_time: 0.633 | end_time 6
#
# 0: 384x640 2 persons, 3 cars, 1 bus, 346.1ms
# Speed: 3.4ms preprocess, 346.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.667 | start_time 0
# current_time: 0.667 | end_time 6
#
# 0: 384x640 2 persons, 3 cars, 1 bus, 280.2ms
# Speed: 3.7ms preprocess, 280.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.700 | start_time 0
# current_time: 0.700 | end_time 6
#
# 0: 384x640 2 persons, 3 cars, 1 bus, 295.9ms
# Speed: 4.9ms preprocess, 295.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.733 | start_time 0
# current_time: 0.733 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 393.2ms
# Speed: 6.6ms preprocess, 393.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.767 | start_time 0
# current_time: 0.767 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 401.1ms
# Speed: 8.5ms preprocess, 401.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.800 | start_time 0
# current_time: 0.800 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 303.3ms
# Speed: 3.7ms preprocess, 303.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.833 | start_time 0
# current_time: 0.833 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 312.7ms
# Speed: 4.8ms preprocess, 312.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 0.867 | start_time 0
# current_time: 0.867 | end_time 6
#
# 0: 384x640 2 persons, 4 cars, 1 bus,
| end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 303.4ms
# Speed: 5.4ms preprocess, 303.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.038 | start_time 0
# current_time: 5.038 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 332.2ms
# Speed: 5.4ms preprocess, 332.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.072 | start_time 0
# current_time: 5.072 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 556.0ms
# Speed: 9.0ms preprocess, 556.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.105 | start_time 0
# current_time: 5.105 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 471.6ms
# Speed: 10.7ms preprocess, 471.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.138 | start_time 0
# current_time: 5.138 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 448.3ms
# Speed: 8.2ms preprocess, 448.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.172 | start_time 0
# current_time: 5.172 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 470.3ms
# Speed: 6.7ms preprocess, 470.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.205 | start_time 0
# current_time: 5.205 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 567.9ms
# Speed: 9.0ms preprocess, 567.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.238 | start_time 0
# current_time: 5.238 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 492.4ms
# Speed: 4.2ms preprocess, 492.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.272 | start_time 0
# current_time: 5.272 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 623.6ms
# Speed: 28.2ms preprocess, 623.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.305 | start_time 0
# current_time: 5.305 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 379.1ms
# Speed: 5.4ms preprocess, 379.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.338 | start_time 0
# current_time: 5.338 | end_time 6
#
# 0: 384x640 1 person, 4 cars, 1 bus, 512.3ms
# Speed: 7.3ms preprocess, 512.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.372 | start_time 0
# current_time: 5.372 | end_time 6
#
# 0: 384x640 1 person, 4 cars, 1 bus, 470.8ms
# Speed: 11.1ms preprocess, 470.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.405 | start_time 0
# current_time: 5.405 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 351.7ms
# Speed: 5.1ms preprocess, 351.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.438 | start_time 0
# current_time: 5.438 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 352.8ms
# Speed: 5.2ms preprocess, 352.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.472 | start_time 0
# current_time: 5.472 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 313.5ms
# Speed: 5.6ms preprocess, 313.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.505 | start_time 0
# current_time: 5.505 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 287.1ms
# Speed: 5.6ms preprocess, 287.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.538 | start_time 0
# current_time: 5.538 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 322.4ms
# Speed: 7.3ms preprocess, 322.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.572 | start_time 0
# current_time: 5.572 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 293.3ms
# Speed: 8.0ms preprocess, 293.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.605 | start_time 0
# current_time: 5.605 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 442.0ms
# Speed: 7.1ms preprocess, 442.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.638 | start_time 0
# current_time: 5.638 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 445.0ms
# Speed: 5.2ms preprocess, 445.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.672 | start_time 0
# current_time: 5.672 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 435.8ms
# Speed: 7.2ms preprocess, 435.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.705 | start_time 0
# current_time: 5.705 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 542.6ms
# Speed: 19.8ms preprocess, 542.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.738 | start_time 0
# current_time: 5.738 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 424.7ms
# Speed: 5.8ms preprocess, 424.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.772 | start_time 0
# current_time: 5.772 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 404.7ms
# Speed: 5.0ms preprocess, 404.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.805 | start_time 0
# current_time: 5.805 | end_time 6
#
# 0: 384x640 1 person, 4 cars, 1 bus, 322.2ms
# Speed: 6.9ms preprocess, 322.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.838 | start_time 0
# current_time: 5.838 | end_time 6
#
# 0: 384x640 1 person, 4 cars, 1 truck, 390.1ms
# Speed: 11.9ms preprocess, 390.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.872 | start_time 0
# current_time: 5.872 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 416.2ms
# Speed: 8.1ms preprocess, 416.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.905 | start_time 0
# current_time: 5.905 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 439.5ms
# Speed: 7.2ms preprocess, 439.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.938 | start_time 0
# current_time: 5.938 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 bus, 362.7ms
# Speed: 5.2ms preprocess, 362.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 5.972 | start_time 0
# current_time: 5.972 | end_time 6
#
# 0: 384x640 1 person, 3 cars, 1 truck, 465.8ms
# Speed: 7.5ms preprocess, 465.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# current_time: 6.005 | start_time 0
#
# Out of Loop
#
# CPU times: user 2min 53s, sys: 16 s, total: 3min 9s
# Wall time: 1min 50s
